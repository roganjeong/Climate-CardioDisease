# %% [markdown]
# # OPTUNA를 통해 best model 선택 후, SHAP 을 통해 해석

# %% [markdown]
# ### 모델학습용 데이터 불러오기

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
train = pd.read_csv("C:/Users/user/OneDrive/바탕 화면/JHLee/공모전/3. 기상청 날씨에 따른 혈관질환 발병률 예측/데이터/TRAIN_tree_with_파생변수0804.csv")
train.drop(['Unnamed: 0', 'yyyymmdd'], axis=1, inplace=True)

#-----------------------------------------------------------------------------------

train_Gangwon_1 = train[(train['add'] == '강원') & (train['sex'] == 1)]
train_Gangwon_2 = train[(train['add'] == '강원') & (train['sex'] == 2)]

train_Gyeonggi_1 = train[(train['add'] == '경기') & (train['sex'] == 1)]
train_Gyeonggi_2 = train[(train['add'] == '경기') & (train['sex'] == 2)]

train_Gyeongnam_1 = train[(train['add'] == '경남') & (train['sex'] == 1)]
train_Gyeongnam_2 = train[(train['add'] == '경남') & (train['sex'] == 2)]

train_Gyeongbuk_1 = train[(train['add'] == '경북') & (train['sex'] == 1)]
train_Gyeongbuk_2 = train[(train['add'] == '경북') & (train['sex'] == 2)]

train_Gwangju_1 = train[(train['add'] == '광주') & (train['sex'] == 1)]
train_Gwangju_2 = train[(train['add'] == '광주') & (train['sex'] == 2)]

train_Daegu_1 = train[(train['add'] == '대구') & (train['sex'] == 1)]
train_Daegu_2 = train[(train['add'] == '대구') & (train['sex'] == 2)]

train_Daejeon_1 = train[(train['add'] == '대전') & (train['sex'] == 1)]
train_Daejeon_2 = train[(train['add'] == '대전') & (train['sex'] == 2)]

train_Busan_1 = train[(train['add'] == '부산') & (train['sex'] == 1)]
train_Busan_2 = train[(train['add'] == '부산') & (train['sex'] == 2)]

train_Seoul_1 = train[(train['add'] == '서울') & (train['sex'] == 1)]
train_Seoul_2 = train[(train['add'] == '서울') & (train['sex'] == 2)]

train_Sejong_1 = train[(train['add'] == '세종') & (train['sex'] == 1)]
train_Sejong_2 = train[(train['add'] == '세종') & (train['sex'] == 2)]

train_Ulsan_1 = train[(train['add'] == '울산') & (train['sex'] == 1)]
train_Ulsan_2 = train[(train['add'] == '울산') & (train['sex'] == 2)]

train_Incheon_1 = train[(train['add'] == '인천') & (train['sex'] == 1)]
train_Incheon_2 = train[(train['add'] == '인천') & (train['sex'] == 2)]

train_Jeonnam_1 = train[(train['add'] == '전남') & (train['sex'] == 1)]
train_Jeonnam_2 = train[(train['add'] == '전남') & (train['sex'] == 2)]

train_Jeonbuk_1 = train[(train['add'] == '전북') & (train['sex'] == 1)]
train_Jeonbuk_2 = train[(train['add'] == '전북') & (train['sex'] == 2)]

train_Jeju_1 = train[(train['add'] == '제주') & (train['sex'] == 1)]
train_Jeju_2 = train[(train['add'] == '제주') & (train['sex'] == 2)]

train_Chungnam_1 = train[(train['add'] == '충남') & (train['sex'] == 1)]
train_Chungnam_2 = train[(train['add'] == '충남') & (train['sex'] == 2)]

train_Chungbuk_1 = train[(train['add'] == '충북') & (train['sex'] == 1)]
train_Chungbuk_2 = train[(train['add'] == '충북') & (train['sex'] == 2)]

#-----------------------------------------------------------------------------------

train_Gangwon_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Gangwon_2.drop(['add', 'sex'], axis=1, inplace=True)

train_Gyeonggi_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Gyeonggi_2.drop(['add', 'sex'], axis=1, inplace=True)

train_Gyeongnam_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Gyeongnam_2.drop(['add', 'sex'], axis=1, inplace=True)

train_Gyeongbuk_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Gyeongbuk_2.drop(['add', 'sex'], axis=1, inplace=True)

train_Gwangju_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Gwangju_2.drop(['add', 'sex'], axis=1, inplace=True)

train_Daegu_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Daegu_2.drop(['add', 'sex'], axis=1, inplace=True)

train_Daejeon_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Daejeon_2.drop(['add', 'sex'], axis=1, inplace=True)

train_Busan_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Busan_2.drop(['add', 'sex'], axis=1, inplace=True)

train_Seoul_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Seoul_2.drop(['add', 'sex'], axis=1, inplace=True)

train_Sejong_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Sejong_2.drop(['add', 'sex'], axis=1, inplace=True)

train_Ulsan_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Ulsan_2.drop(['add', 'sex'], axis=1, inplace=True)

train_Incheon_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Incheon_2.drop(['add', 'sex'], axis=1, inplace=True)

train_Jeonnam_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Jeonnam_2.drop(['add', 'sex'], axis=1, inplace=True)

train_Jeonbuk_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Jeonbuk_2.drop(['add', 'sex'], axis=1, inplace=True)

train_Jeju_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Jeju_2.drop(['add', 'sex'], axis=1, inplace=True)

train_Chungnam_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Chungnam_2.drop(['add', 'sex'], axis=1, inplace=True)

train_Chungbuk_1.drop(['add', 'sex'], axis=1, inplace=True)
train_Chungbuk_2.drop(['add', 'sex'], axis=1, inplace=True)

#------------------------------------------------------------------------

y_train_Gangwon_1 = train_Gangwon_1['frequency']
y_train_Gangwon_2 = train_Gangwon_2['frequency']
train_Gangwon_1.drop(['frequency'], axis=1, inplace=True)
train_Gangwon_2.drop(['frequency'], axis=1, inplace=True)

y_train_Gyeonggi_1 = train_Gyeonggi_1['frequency']
y_train_Gyeonggi_2 = train_Gyeonggi_2['frequency']
train_Gyeonggi_1.drop(['frequency'], axis=1, inplace=True)
train_Gyeonggi_2.drop(['frequency'], axis=1, inplace=True)

y_train_Gyeongnam_1 = train_Gyeongnam_1['frequency']
y_train_Gyeongnam_2 = train_Gyeongnam_2['frequency']
train_Gyeongnam_1.drop(['frequency'], axis=1, inplace=True)
train_Gyeongnam_2.drop(['frequency'], axis=1, inplace=True)

y_train_Gyeongbuk_1 = train_Gyeongbuk_1['frequency']
y_train_Gyeongbuk_2 = train_Gyeongbuk_2['frequency']
train_Gyeongbuk_1.drop(['frequency'], axis=1, inplace=True)
train_Gyeongbuk_2.drop(['frequency'], axis=1, inplace=True)

y_train_Gwangju_1 = train_Gwangju_1['frequency']
y_train_Gwangju_2 = train_Gwangju_2['frequency']
train_Gwangju_1.drop(['frequency'], axis=1, inplace=True)
train_Gwangju_2.drop(['frequency'], axis=1, inplace=True)

y_train_Daegu_1 = train_Daegu_1['frequency']
y_train_Daegu_2 = train_Daegu_2['frequency']
train_Daegu_1.drop(['frequency'], axis=1, inplace=True)
train_Daegu_2.drop(['frequency'], axis=1, inplace=True)

y_train_Daejeon_1 = train_Daejeon_1['frequency']
y_train_Daejeon_2 = train_Daejeon_2['frequency']
train_Daejeon_1.drop(['frequency'], axis=1, inplace=True)
train_Daejeon_2.drop(['frequency'], axis=1, inplace=True)

y_train_Busan_1 = train_Busan_1['frequency']
y_train_Busan_2 = train_Busan_2['frequency']
train_Busan_1.drop(['frequency'], axis=1, inplace=True)
train_Busan_2.drop(['frequency'], axis=1, inplace=True)

y_train_Seoul_1 = train_Seoul_1['frequency']
y_train_Seoul_2 = train_Seoul_2['frequency']
train_Seoul_1.drop(['frequency'], axis=1, inplace=True)
train_Seoul_2.drop(['frequency'], axis=1, inplace=True)

y_train_Sejong_1 = train_Sejong_1['frequency']
y_train_Sejong_2 = train_Sejong_2['frequency']
train_Sejong_1.drop(['frequency'], axis=1, inplace=True)
train_Sejong_2.drop(['frequency'], axis=1, inplace=True)

y_train_Ulsan_1 = train_Ulsan_1['frequency']
y_train_Ulsan_2 = train_Ulsan_2['frequency']
train_Ulsan_1.drop(['frequency'], axis=1, inplace=True)
train_Ulsan_2.drop(['frequency'], axis=1, inplace=True)

y_train_Incheon_1 = train_Incheon_1['frequency']
y_train_Incheon_2 = train_Incheon_2['frequency']
train_Incheon_1.drop(['frequency'], axis=1, inplace=True)
train_Incheon_2.drop(['frequency'], axis=1, inplace=True)

y_train_Jeonnam_1 = train_Jeonnam_1['frequency']
y_train_Jeonnam_2 = train_Jeonnam_2['frequency']
train_Jeonnam_1.drop(['frequency'], axis=1, inplace=True)
train_Jeonnam_2.drop(['frequency'], axis=1, inplace=True)

y_train_Jeonbuk_1 = train_Jeonbuk_1['frequency']
y_train_Jeonbuk_2 = train_Jeonbuk_2['frequency']
train_Jeonbuk_1.drop(['frequency'], axis=1, inplace=True)
train_Jeonbuk_2.drop(['frequency'], axis=1, inplace=True)

y_train_Jeju_1 = train_Jeju_1['frequency']
y_train_Jeju_2 = train_Jeju_2['frequency']
train_Jeju_1.drop(['frequency'], axis=1, inplace=True)
train_Jeju_2.drop(['frequency'], axis=1, inplace=True)

y_train_Chungnam_1 = train_Chungnam_1['frequency']
y_train_Chungnam_2 = train_Chungnam_2['frequency']
train_Chungnam_1.drop(['frequency'], axis=1, inplace=True)
train_Chungnam_2.drop(['frequency'], axis=1, inplace=True)

y_train_Chungbuk_1 = train_Chungbuk_1['frequency']
y_train_Chungbuk_2 = train_Chungbuk_2['frequency']
train_Chungbuk_1.drop(['frequency'], axis=1, inplace=True)
train_Chungbuk_2.drop(['frequency'], axis=1, inplace=True)

# %%
test = pd.read_csv("C:/Users/user/OneDrive/바탕 화면/JHLee/공모전/3. 기상청 날씨에 따른 혈관질환 발병률 예측/데이터/TEST_with_파생변수0804.csv", header = 0 )

test_Gangwon_1 = test[(test['add'] == '강원') & (test['sex'] == 1)]
test_Gangwon_2 = test[(test['add'] == '강원') & (test['sex'] == 2)]

test_Gyeonggi_1 = test[(test['add'] == '경기') & (test['sex'] == 1)]
test_Gyeonggi_2 = test[(test['add'] == '경기') & (test['sex'] == 2)]

test_Gyeongnam_1 = test[(test['add'] == '경남') & (test['sex'] == 1)]
test_Gyeongnam_2 = test[(test['add'] == '경남') & (test['sex'] == 2)]

test_Gyeongbuk_1 = test[(test['add'] == '경북') & (test['sex'] == 1)]
test_Gyeongbuk_2 = test[(test['add'] == '경북') & (test['sex'] == 2)]

test_Gwangju_1 = test[(test['add'] == '광주') & (test['sex'] == 1)]
test_Gwangju_2 = test[(test['add'] == '광주') & (test['sex'] == 2)]

test_Daegu_1 = test[(test['add'] == '대구') & (test['sex'] == 1)]
test_Daegu_2 = test[(test['add'] == '대구') & (test['sex'] == 2)]

test_Daejeon_1 = test[(test['add'] == '대전') & (test['sex'] == 1)]
test_Daejeon_2 = test[(test['add'] == '대전') & (test['sex'] == 2)]

test_Busan_1 = test[(test['add'] == '부산') & (test['sex'] == 1)]
test_Busan_2 = test[(test['add'] == '부산') & (test['sex'] == 2)]

test_Seoul_1 = test[(test['add'] == '서울') & (test['sex'] == 1)]
test_Seoul_2 = test[(test['add'] == '서울') & (test['sex'] == 2)]

test_Sejong_1 = test[(test['add'] == '세종') & (test['sex'] == 1)]
test_Sejong_2 = test[(test['add'] == '세종') & (test['sex'] == 2)]

test_Ulsan_1 = test[(test['add'] == '울산') & (test['sex'] == 1)]
test_Ulsan_2 = test[(test['add'] == '울산') & (test['sex'] == 2)]

test_Incheon_1 = test[(test['add'] == '인천') & (test['sex'] == 1)]
test_Incheon_2 = test[(test['add'] == '인천') & (test['sex'] == 2)]

test_Jeonnam_1 = test[(test['add'] == '전남') & (test['sex'] == 1)]
test_Jeonnam_2 = test[(test['add'] == '전남') & (test['sex'] == 2)]

test_Jeonbuk_1 = test[(test['add'] == '전북') & (test['sex'] == 1)]
test_Jeonbuk_2 = test[(test['add'] == '전북') & (test['sex'] == 2)]

test_Jeju_1 = test[(test['add'] == '제주') & (test['sex'] == 1)]
test_Jeju_2 = test[(test['add'] == '제주') & (test['sex'] == 2)]

test_Chungnam_1 = test[(test['add'] == '충남') & (test['sex'] == 1)]
test_Chungnam_2 = test[(test['add'] == '충남') & (test['sex'] == 2)]

test_Chungbuk_1 = test[(test['add'] == '충북') & (test['sex'] == 1)]
test_Chungbuk_2 = test[(test['add'] == '충북') & (test['sex'] == 2)]

#-----------------------------------------------------------------------------

test_Gangwon_1.drop(['Unnamed: 0','Unnamed..0','yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Gangwon_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

test_Gyeonggi_1.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Gyeonggi_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

test_Gyeongnam_1.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Gyeongnam_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

test_Gyeongbuk_1.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Gyeongbuk_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

test_Gwangju_1.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Gwangju_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

test_Daegu_1.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Daegu_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

test_Daejeon_1.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Daejeon_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

test_Busan_1.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Busan_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

test_Seoul_1.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Seoul_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

test_Sejong_1.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Sejong_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

test_Ulsan_1.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Ulsan_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

test_Incheon_1.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Incheon_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

test_Jeonnam_1.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Jeonnam_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

test_Jeonbuk_1.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Jeonbuk_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

test_Jeju_1.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Jeju_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

test_Chungnam_1.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Chungnam_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

test_Chungbuk_1.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)
test_Chungbuk_2.drop(['Unnamed: 0','Unnamed..0', 'yyyymmdd', 'frequency', 'add', 'sex'], axis=1, inplace=True)

# %% [markdown]
# ### 모델학습

# %%
import lightgbm as lgb
import shap
from lightgbm import LGBMRegressor, LGBMRanker, LGBMClassifier
from sklearn.ensemble import RandomForestRegressor
import optuna
from optuna import Trial
from optuna.samplers import TPESampler
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn import datasets
import sklearn.datasets
import sklearn.metrics
from sklearn.model_selection import train_test_split
import xgboost as xgb
import psutil
import time 
# from sklearn.metrics import classification_report
# from sklearn.metrics import recall_score
# from sklearn.metrics import precision_score
from sklearn.metrics import mean_squared_error
# from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ## 최종 Random Forest 모델

# %% [markdown]
# 선별된 시도별/성별 : 강원 1, 강원 2, 대구 1, 대전 1, 전남 2, 제주 1, 충북 1

# %%
rf_Gangwon_1 = RandomForestRegressor(max_depth = 10, 
                                     max_leaf_nodes = 70, 
                                     n_estimators = 242,
                                     ccp_alpha = 0.04364)
rf_Gangwon_1.fit(train_Gangwon_1, y_train_Gangwon_1)
pred_Gangwon_1=rf_Gangwon_1.predict(test_Gangwon_1)

# %%
rf_Gangwon_2 = RandomForestRegressor(max_depth = 4, 
                                     max_leaf_nodes = 484, 
                                     n_estimators = 141,
                                     ccp_alpha = 0.02401)
rf_Gangwon_2.fit(train_Gangwon_2, y_train_Gangwon_2)
pred_Gangwon_2=rf_Gangwon_2.predict(test_Gangwon_2)

# %%
rf_Daegu_1 = RandomForestRegressor(max_depth = 10, 
                                     max_leaf_nodes = 461, 
                                     n_estimators = 500,
                                     ccp_alpha = 0.022992)
rf_Daegu_1.fit(train_Daegu_1, y_train_Daegu_1)
pred_Daegu_1=rf_Daegu_1.predict(test_Daegu_1)

# %%
rf_Daejeon_1 = RandomForestRegressor(max_depth = 3, 
                                     max_leaf_nodes = 506, 
                                     n_estimators = 310,
                                     ccp_alpha = 0.0161)
rf_Daejeon_1.fit(train_Daejeon_1, y_train_Daejeon_1)
pred_Daejeon_1=rf_Daejeon_1.predict(test_Daejeon_1)

# %%
rf_Jeonnam_2 = RandomForestRegressor(max_depth = 4, 
                                     max_leaf_nodes = 651, 
                                     n_estimators = 464,
                                     ccp_alpha = 0.016249)
rf_Jeonnam_2.fit(train_Jeonnam_2, y_train_Jeonnam_2)
pred_Jeonnam_2=rf_Jeonnam_2.predict(test_Jeonnam_2)

# %%
rf_Jeju_1 = RandomForestRegressor(max_depth = 20, 
                                  max_leaf_nodes = 340, 
                                  n_estimators = 500,
                                  ccp_alpha = 0.130184)
rf_Jeju_1.fit(train_Jeju_1, y_train_Jeju_1)
pred_Jeju_1=rf_Jeju_1.predict(test_Jeju_1)

# %%
rf_Chungbuk_1 = RandomForestRegressor(max_depth = 3, 
                                     max_leaf_nodes = 606, 
                                     n_estimators = 223,
                                     ccp_alpha = 0.021476)
rf_Chungbuk_1.fit(train_Chungbuk_1, y_train_Chungbuk_1)
pred_Chungbuk_1=rf_Chungbuk_1.predict(test_Chungbuk_1)

# %% [markdown]
# ## 최종 LightGBM 모델

# %% [markdown]
# 선별된 시도별/성별 : 경기 1, 경기 2, 경남 1, 경남 2, 경북 1, 경북 2, 광주 1, 광주 2, 대구 1, 대구 2, 대전 2, 부산 1, 부산 2, 서울 1, 서울 2, 세종 2, 울산 1, 울산 2, 인천 2, 전남 1, 전북 1, 제주 2, 충남 2, 충북 2

# %%
lgb_Gyeonggi_1 = lgb.LGBMRegressor(num_leaves = 50,
                                   max_depth = 4,
                                   boosting = 'gbdt',
                                   learning_rate = 0.0266,
                                   n_estimators = 157,
                                   min_child_samples = 11,
                                   colsample_bytree = 0.672,
                                   subsample = 0.605,
                                   reg_alpha = 0.668, 
                                   reg_lambda = 9.7423, 
                                   random_state = 6)
lgb_Gyeonggi_1.fit(train_Gyeonggi_1,y_train_Gyeonggi_1)
pred_Gyeonggi_1=lgb_Gyeonggi_1.predict(test_Gyeonggi_1)

# %%
lgb_Gyeonggi_2 = lgb.LGBMRegressor(num_leaves = 238,
                                   max_depth = 3,
                                   boosting = 'gbdt',
                                   learning_rate = 0.0292,
                                   n_estimators = 185,
                                   min_child_samples = 31,
                                   colsample_bytree = 0.662, 
                                   reg_alpha = 0.296, 
                                   reg_lambda = 8.5, 
                                   random_state = 6)
lgb_Gyeonggi_2.fit(train_Gyeonggi_2,y_train_Gyeonggi_2)
pred_Gyeonggi_2=lgb_Gyeonggi_2.predict(test_Gyeonggi_2)

# %%
lgb_Gyeongnam_1 = lgb.LGBMRegressor(num_leaves = 17,
                                   max_depth = 9,
                                   boosting = 'gbdt',
                                   learning_rate = 0.0163,
                                   n_estimators = 125,
                                   min_child_samples = 34,
                                   colsample_bytree =0.6478 , 
                                   reg_alpha = 0.71, 
                                   reg_lambda = 6.884, 
                                   random_state = 6)
lgb_Gyeongnam_1.fit(train_Gyeongnam_1,y_train_Gyeongnam_1)
pred_Gyeongnam_1=lgb_Gyeongnam_1.predict(test_Gyeongnam_1)

# %%
lgb_Gyeongnam_2 = lgb.LGBMRegressor(num_leaves = 60,
                                   max_depth = 3,
                                   boosting = 'gbdt',
                                   learning_rate = 0.027,
                                   n_estimators = 187,
                                   min_child_samples = 25,
                                   colsample_bytree = 0.8359,
                                   subsample = 0.5788,
                                   reg_alpha = 0.99995, 
                                   reg_lambda = 9.2691, 
                                   random_state = 6)
lgb_Gyeongnam_2.fit(train_Gyeongnam_2,y_train_Gyeongnam_2)
pred_Gyeongnam_2=lgb_Gyeongnam_2.predict(test_Gyeongnam_2)

# %%
lgb_Gyeongbuk_1 = lgb.LGBMRegressor(num_leaves = 25,
                                   max_depth = 3,
                                   boosting = 'gbdt',
                                   learning_rate = 0.0233,
                                   n_estimators = 185,
                                   min_child_samples = 27,
                                   colsample_bytree = 0.88,
                                   subsample = 0.968,
                                   reg_alpha = 0.76, 
                                   reg_lambda = 8.47, 
                                   random_state = 6)
lgb_Gyeongbuk_1.fit(train_Gyeongbuk_1,y_train_Gyeongbuk_1)
pred_Gyeongbuk_1=lgb_Gyeongbuk_1.predict(test_Gyeongbuk_1)

# %%
lgb_Gyeongbuk_2 = lgb.LGBMRegressor(num_leaves = 20,
                                   max_depth = 3,
                                   boosting = 'gbdt',
                                   learning_rate = 0.02249,
                                   n_estimators = 92,
                                   min_child_samples = 15,
                                   colsample_bytree = 0.855,
                                   subsample = 0.947,
                                   reg_alpha = 0.377, 
                                   reg_lambda = 6.246, 
                                   random_state = 6)
lgb_Gyeongbuk_2.fit(train_Gyeongbuk_2,y_train_Gyeongbuk_2)
pred_Gyeongbuk_2=lgb_Gyeongbuk_2.predict(test_Gyeongbuk_2)

# %%
lgb_Gwangju_1 = lgb.LGBMRegressor(num_leaves = 221,
                                   max_depth = 7,
                                   boosting = 'gbdt',
                                   learning_rate = 0.0137,
                                   n_estimators = 83,
                                   min_child_samples = 11,
                                   colsample_bytree = 0.865,
                                   subsample = 0.89,
                                   reg_alpha = 0.386, 
                                   reg_lambda = 6.74, 
                                   random_state = 6)
lgb_Gwangju_1.fit(train_Gwangju_1,y_train_Gwangju_1)
pred_Gwangju_1=lgb_Gwangju_1.predict(test_Gwangju_1)

# %%
lgb_Gwangju_2 = lgb.LGBMRegressor(num_leaves = 19,
                                   max_depth = 1,
                                   boosting = 'gbdt',
                                   learning_rate = 0.024,
                                   n_estimators = 124,
                                   min_child_samples = 29,
                                   colsample_bytree = 0.847,
                                   subsample = 0.6344,
                                   reg_alpha = 0.893, 
                                   reg_lambda = 8.387, 
                                   random_state = 6)
lgb_Gwangju_2.fit(train_Gwangju_2,y_train_Gwangju_2)
pred_Gwangju_2=lgb_Gwangju_2.predict(test_Gwangju_2)

# %%
lgb_Daegu_1 = lgb.LGBMRegressor(num_leaves = 12,
                                   max_depth = 17,
                                   boosting = 'gbdt',
                                   learning_rate = 0.018,
                                   n_estimators = 85,
                                   min_child_samples = 22,
                                   colsample_bytree = 0.6445,
                                   subsample = 0.62,
                                   reg_alpha = 0.758, 
                                   reg_lambda = 7.517, 
                                   random_state = 6)
lgb_Daegu_1.fit(train_Daegu_1,y_train_Daegu_1)
pred_Daegu_1=lgb_Daegu_1.predict(test_Daegu_1)

# %%
lgb_Daegu_2 = lgb.LGBMRegressor(num_leaves = 26,
                                   max_depth = 3,
                                   boosting = 'gbdt',
                                   learning_rate = 0.0165,
                                   n_estimators = 196,
                                   min_child_samples = 37,
                                   colsample_bytree = 0.614,
                                   subsample = 0.5842,
                                   reg_alpha = 0.0312, 
                                   reg_lambda = 7.5672, 
                                   random_state = 6)
lgb_Daegu_2.fit(train_Daegu_2,y_train_Daegu_2)
pred_Daegu_2=lgb_Daegu_2.predict(test_Daegu_2)

# %%
lgb_Daejeon_2 = lgb.LGBMRegressor(num_leaves = 190,
                                   max_depth = 7,
                                   boosting = 'gbdt',
                                   learning_rate = 0.0032,
                                   n_estimators = 51,
                                   min_child_samples = 11,
                                   colsample_bytree = 0.727,
                                   subsample = 0.6927,
                                   reg_alpha = 0.83, 
                                   reg_lambda = 8.74, 
                                   random_state = 6)
lgb_Daejeon_2.fit(train_Daejeon_2,y_train_Daejeon_2)
pred_Daejeon_2=lgb_Daejeon_2.predict(test_Daejeon_2)

# %%
lgb_Busan_1 = lgb.LGBMRegressor(num_leaves = 74,
                                   max_depth = 3,
                                   boosting = 'gbdt',
                                   learning_rate = 0.02,
                                   n_estimators = 168,
                                   min_child_samples = 37,
                                   colsample_bytree = 0.83,
                                   subsample = 0.5876,
                                   reg_alpha = 0.413, 
                                   reg_lambda = 9.2332, 
                                   random_state = 6)
lgb_Busan_1.fit(train_Busan_1,y_train_Busan_1)
pred_Busan_1=lgb_Busan_1.predict(test_Busan_1)

# %%
lgb_Busan_2 = lgb.LGBMRegressor(num_leaves = 125,
                                   max_depth = 3,
                                   boosting = 'gbdt',
                                   learning_rate = 0.02265,
                                   n_estimators = 121,
                                   min_child_samples = 28,
                                   colsample_bytree = 0.739,
                                   subsample = 0.723,
                                   reg_alpha = 0.944, 
                                   reg_lambda = 5.486, 
                                   random_state = 6)
lgb_Busan_2.fit(train_Busan_2,y_train_Busan_2)
pred_Busan_2=lgb_Busan_2.predict(test_Busan_2)

# %%
lgb_Seoul_1 = lgb.LGBMRegressor(num_leaves = 21,
                                   max_depth = 3,
                                   boosting = 'gbdt',
                                   learning_rate = 0.0192,
                                   n_estimators = 136,
                                   min_child_samples = 21,
                                   colsample_bytree = 0.75,
                                   subsample = 0.6,
                                   reg_alpha = 0.695, 
                                   reg_lambda = 5.349, 
                                   random_state = 6)
lgb_Seoul_1.fit(train_Seoul_1,y_train_Seoul_1)
pred_Seoul_1=lgb_Seoul_1.predict(test_Seoul_1)

# %%
lgb_Seoul_2 = lgb.LGBMRegressor(num_leaves = 69,
                                   max_depth = 3,
                                   boosting = 'gbdt',
                                   learning_rate = 0.015,
                                   n_estimators = 160,
                                   min_child_samples = 25,
                                   colsample_bytree = 0.6,
                                   subsample = 0.648,
                                   reg_alpha = 0.92, 
                                   reg_lambda = 7.8488, 
                                   random_state = 6)
lgb_Seoul_2.fit(train_Seoul_2,y_train_Seoul_2)
pred_Seoul_2=lgb_Seoul_2.predict(test_Seoul_2)

# %%
lgb_Sejong_1 = lgb.LGBMRegressor(num_leaves = 11,
                                   max_depth = 9,
                                   boosting = 'gbdt',
                                   learning_rate = 0.00318,
                                   n_estimators = 66,
                                   min_child_samples = 13,
                                   colsample_bytree = 0.658,
                                   subsample = 0.698,
                                   reg_alpha = 0.942, 
                                   reg_lambda = 8.577, 
                                   random_state = 6)
lgb_Sejong_1.fit(train_Sejong_1,y_train_Sejong_1)
pred_Sejong_1=lgb_Sejong_1.predict(test_Sejong_1)

# %%
lgb_Sejong_2 = lgb.LGBMRegressor(num_leaves = 90,
                                   max_depth = 3,
                                   boosting = 'gbdt',
                                   learning_rate = 0.0058,
                                   n_estimators = 20,
                                   min_child_samples = 12,
                                   colsample_bytree = 0.811,
                                   subsample = 0.8224,
                                   reg_alpha = 0.997, 
                                   reg_lambda = 9.893, 
                                   random_state = 6)
lgb_Sejong_2.fit(train_Sejong_2,y_train_Sejong_2)
pred_Sejong_2=lgb_Sejong_2.predict(test_Sejong_2)

# %%
lgb_Ulsan_1 = lgb.LGBMRegressor(num_leaves = 228,
                                   max_depth = 3,
                                   boosting = 'gbdt',
                                   learning_rate = 0.0063,
                                   n_estimators = 136,
                                   min_child_samples = 12,
                                   colsample_bytree = 0.876,
                                   subsample = 0.923,
                                   reg_alpha = 0.0081, 
                                   reg_lambda = 7.418, 
                                   random_state = 6)
lgb_Ulsan_1.fit(train_Ulsan_1,y_train_Ulsan_1)
pred_Ulsan_1=lgb_Ulsan_1.predict(test_Ulsan_1)

# %%
lgb_Ulsan_2 = lgb.LGBMRegressor(num_leaves = 231,
                                   max_depth = 3,
                                   boosting = 'gbdt',
                                   learning_rate = 0.0115,
                                   n_estimators = 49,
                                   min_child_samples = 17,
                                   colsample_bytree = 0.8,
                                   subsample = 0.87,
                                   reg_alpha = 0.795, 
                                   reg_lambda = 8.24, 
                                   random_state = 6)
lgb_Ulsan_2.fit(train_Ulsan_2,y_train_Ulsan_2)
pred_Ulsan_2=lgb_Ulsan_2.predict(test_Ulsan_2)

# %%
lgb_Incheon_1 = lgb.LGBMRegressor(num_leaves = 12,
                                   max_depth = 18,
                                   boosting = 'gbdt',
                                   learning_rate = 0.0056,
                                   n_estimators = 42,
                                   min_child_samples = 12,
                                   colsample_bytree = 0.6249,
                                   subsample = 0.8983,
                                   reg_alpha = 0.128, 
                                   reg_lambda = 5.63, 
                                   random_state = 6)
lgb_Incheon_1.fit(train_Incheon_1,y_train_Incheon_1)
pred_Incheon_1=lgb_Incheon_1.predict(test_Incheon_1)

# %%
lgb_Incheon_2 = lgb.LGBMRegressor(num_leaves = 15,
                                   max_depth = 20,
                                   boosting = 'gbdt',
                                   learning_rate = 0.0056,
                                   n_estimators = 127,
                                   min_child_samples = 16,
                                   colsample_bytree = 0.76,
                                   subsample = 0.5,
                                   reg_alpha = 0.71, 
                                   reg_lambda = 9.852, 
                                   random_state = 6)
lgb_Incheon_2.fit(train_Incheon_2,y_train_Incheon_2)
pred_Incheon_2=lgb_Incheon_2.predict(test_Incheon_2)

# %%
lgb_Jeonnam_1 = lgb.LGBMRegressor(num_leaves = 190,
                                   max_depth = 3,
                                   boosting = 'gbdt',
                                   learning_rate = 0.02455,
                                   n_estimators = 186,
                                   min_child_samples = 28,
                                   colsample_bytree = 0.754,
                                   subsample = 0.88,
                                   reg_alpha = 0.9788, 
                                   reg_lambda = 9.994, 
                                   random_state = 6)
lgb_Jeonnam_1.fit(train_Jeonnam_1,y_train_Jeonnam_1)
pred_Jeonnam_1=lgb_Jeonnam_1.predict(test_Jeonnam_1)

# %%
lgb_Jeonbuk_1 = lgb.LGBMRegressor(num_leaves = 52,
                                   max_depth = 4,
                                   boosting = 'gbdt',
                                   learning_rate = 0.0129,
                                   n_estimators = 141,
                                   min_child_samples = 18,
                                   colsample_bytree = 0.8349,
                                   subsample = 0.527,
                                   reg_alpha = 0.058, 
                                   reg_lambda = 6.266, 
                                   random_state = 6)
lgb_Jeonbuk_1.fit(train_Jeonbuk_1,y_train_Jeonbuk_1)
pred_Jeonbuk_1=lgb_Jeonbuk_1.predict(test_Jeonbuk_1)

# %%
lgb_Jeonbuk_2 = lgb.LGBMRegressor(num_leaves = 22,
                                   max_depth = 6,
                                   boosting = 'gbdt',
                                   learning_rate = 0.0058,
                                   n_estimators = 192,
                                   min_child_samples = 40,
                                   colsample_bytree = 0.735,
                                   subsample = 0.798,
                                   reg_alpha = 0.517, 
                                   reg_lambda = 7.454, 
                                   random_state = 6)
lgb_Jeonbuk_2.fit(train_Jeonbuk_2,y_train_Jeonbuk_2)
pred_Jeonbuk_2=lgb_Jeonbuk_2.predict(test_Jeonbuk_2)

# %%
lgb_Jeju_2 = lgb.LGBMRegressor(num_leaves = 24,
                                   max_depth = 16,
                                   boosting = 'gbdt',
                                   learning_rate = 0.019,
                                   n_estimators = 36,
                                   min_child_samples = 14,
                                   colsample_bytree = 0.7876,
                                   subsample = 0.7853,
                                   reg_alpha = 0.0163, 
                                   reg_lambda = 6.56, 
                                   random_state = 6)
lgb_Jeju_2.fit(train_Jeju_2,y_train_Jeju_2)
pred_Jeju_2=lgb_Jeju_2.predict(test_Jeju_2)

# %%
lgb_Chungnam_2 = lgb.LGBMRegressor(num_leaves = 34,
                                   max_depth = 3,
                                   boosting = 'gbdt',
                                   learning_rate = 0.0044,
                                   n_estimators = 46,
                                   min_child_samples = 27,
                                   colsample_bytree = 0.7089,
                                   subsample = 0.721,
                                   reg_alpha = 0.36, 
                                   reg_lambda = 7.318, 
                                   random_state = 6)
lgb_Chungnam_2.fit(train_Chungnam_2,y_train_Chungnam_2)
pred_Chungnam_2=lgb_Chungnam_2.predict(test_Chungnam_2)

# %%
lgb_Chungbuk_2 = lgb.LGBMRegressor(num_leaves = 12,
                                   max_depth = 16,
                                   boosting = 'gbdt',
                                   learning_rate = 0.011,
                                   n_estimators = 197,
                                   min_child_samples = 12,
                                   colsample_bytree = 0.844,
                                   subsample = 0.745,
                                   reg_alpha = 0.752, 
                                   reg_lambda = 5.63, 
                                   random_state = 6)
lgb_Chungbuk_2.fit(train_Chungbuk_2,y_train_Chungbuk_2)
pred_Chungbuk_2=lgb_Chungbuk_2.predict(test_Chungbuk_2)

# %% [markdown]
# SHAP on LGBM!

# %%
# SHAP on LGBM_seoul1
pred_Seoul_1 = lgb_Seoul_1.predict(test_Seoul_1)
explainer_Seoul_1 = shap.TreeExplainer(lgb_Seoul_1)
shap_values_Seoul_1 = explainer_Seoul_1.shap_values(test_Seoul_1)
np.abs(shap_values_Seoul_1.sum(1) + explainer_Seoul_1.expected_value - pred).max()

pred_Seoul_2 =lgb_Seoul_2.predict(test_Seoul_2)
explainer_Seoul_2 = shap.TreeExplainer(lgb_Seoul_2)
shap_values_Seoul_2 = explainer_Seoul_2.shap_values(test_Seoul_2)
np.abs(shap_values_Seoul_2.sum(1) + explainer_Seoul_2.expected_value - pred).max()

pred_Gyeonggi_1 =lgb_Gyeonggi_1.predict(test_Gyeonggi_1)
explainer_Gyeonggi_1 = shap.TreeExplainer(lgb_Gyeonggi_1)
shap_values_Gyeonggi_1 = explainer_Gyeonggi_1.shap_values(test_Gyeonggi_1)
np.abs(shap_values_Gyeonggi_1.sum(1) + explainer_Gyeonggi_1.expected_value - pred).max()

pred_Gyeonggi_2 =lgb_Gyeonggi_2.predict(test_Gyeonggi_2)
explainer_Gyeonggi_2 = shap.TreeExplainer(lgb_Gyeonggi_2)
shap_values_Gyeonggi_2 = explainer_Gyeonggi_2.shap_values(test_Gyeonggi_2)
np.abs(shap_values_Gyeonggi_2.sum(1) + explainer_Gyeonggi_2.expected_value - pred).max()

pred_Gyeongnam_1 =lgb_Gyeongnam_1.predict(test_Gyeongnam_1)
explainer_Gyeongnam_1 = shap.TreeExplainer(lgb_Gyeongnam_1)
shap_values_Gyeongnam_1 = explainer_Gyeongnam_1.shap_values(test_Gyeongnam_1)
np.abs(shap_values_Gyeongnam_1.sum(1) + explainer_Gyeongnam_1.expected_value - pred).max()

pred_Gyeongnam_2 =lgb_Gyeongnam_2.predict(test_Gyeongnam_2)
explainer_Gyeongnam_2 = shap.TreeExplainer(lgb_Gyeongnam_2)
shap_values_Gyeongnam_2 = explainer_Gyeongnam_2.shap_values(test_Gyeongnam_2)
np.abs(shap_values_Gyeongnam_2.sum(1) + explainer_Gyeongnam_2.expected_value - pred).max()

pred_Gyeongbuk_1 =lgb_Gyeongbuk_1.predict(test_Gyeongbuk_1)
explainer_Gyeongbuk_1 = shap.TreeExplainer(lgb_Gyeongbuk_1)
shap_values_Gyeongbuk_1 = explainer_Gyeongbuk_1.shap_values(test_Gyeongbuk_1)
np.abs(shap_values_Gyeongbuk_1.sum(1) + explainer_Gyeongbuk_1.expected_value - pred).max()

pred_Gyeongbuk_2 =lgb_Gyeongbuk_2.predict(test_Gyeongbuk_2)
explainer_Gyeongbuk_2 = shap.TreeExplainer(lgb_Gyeongbuk_2)
shap_values_Gyeongbuk_2 = explainer_Gyeongbuk_2.shap_values(test_Gyeongbuk_2)
np.abs(shap_values_Gyeongbuk_2.sum(1) + explainer_Gyeongbuk_2.expected_value - pred).max()

pred_Gwangju_1 =lgb_Gwangju_1.predict(test_Gwangju_1)
explainer_Gwangju_1 = shap.TreeExplainer(lgb_Gwangju_1)
shap_values_Gwangju_1 = explainer_Gwangju_1.shap_values(test_Gwangju_1)
np.abs(shap_values_Gwangju_1.sum(1) + explainer_Gwangju_1.expected_value - pred).max()

pred_Gwangju_2 =lgb_Gwangju_1.predict(test_Gwangju_2)
explainer_Gwangju_2 = shap.TreeExplainer(lgb_Gwangju_2)
shap_values_Gwangju_2 = explainer_Gwangju_2.shap_values(test_Gwangju_2)
np.abs(shap_values_Gwangju_2.sum(1) + explainer_Gwangju_2.expected_value - pred).max()

pred_Daegu_1 =lgb_Daegu_1.predict(test_Daegu_1)
explainer_Daegu_1 = shap.TreeExplainer(lgb_Daegu_1)
shap_values_Daegu_1 = explainer_Daegu_1.shap_values(test_Daegu_1)
np.abs(shap_values_Daegu_1.sum(1) + explainer_Daegu_1.expected_value - pred).max()

pred_Daegu_2 =lgb_Daegu_2.predict(test_Daegu_2)
explainer_Daegu_2 = shap.TreeExplainer(lgb_Daegu_2)
shap_values_Daegu_2 = explainer_Daegu_2.shap_values(test_Daegu_2)
np.abs(shap_values_Daegu_2.sum(1) + explainer_Daegu_2.expected_value - pred).max()

pred_Daejeon_2 =lgb_Daejeon_2.predict(test_Daejeon_2)
explainer_Daejeon_2 = shap.TreeExplainer(lgb_Daejeon_2)
shap_values_Daejeon_2 = explainer_Daejeon_2.shap_values(test_Daejeon_2)
np.abs(shap_values_Daejeon_2.sum(1) + explainer_Daejeon_2.expected_value - pred).max()

pred_Busan_1 =lgb_Busan_1.predict(test_Busan_1)
explainer_Busan_1 = shap.TreeExplainer(lgb_Busan_1)
shap_values_Busan_1 = explainer_Busan_1.shap_values(test_Busan_1)
np.abs(shap_values_Busan_1.sum(1) + explainer_Busan_1.expected_value - pred).max()

pred_Busan_2 =lgb_Busan_2.predict(test_Busan_2)
explainer_Busan_2 = shap.TreeExplainer(lgb_Busan_2)
shap_values_Busan_2 = explainer_Busan_2.shap_values(test_Busan_2)
np.abs(shap_values_Busan_2.sum(1) + explainer_Busan_2.expected_value - pred).max()

pred_Sejong_1 =lgb_Sejong_1.predict(test_Sejong_1)
explainer_Sejong_1 = shap.TreeExplainer(lgb_Sejong_1)
shap_values_Sejong_1 = explainer_Sejong_1.shap_values(test_Sejong_1)
np.abs(shap_values_Sejong_1.sum(1) + explainer_Sejong_1.expected_value - pred).max()

pred_Sejong_2 =lgb_Sejong_2.predict(test_Sejong_2)
explainer_Sejong_2 = shap.TreeExplainer(lgb_Sejong_2)
shap_values_Sejong_2 = explainer_Sejong_2.shap_values(test_Sejong_2)
np.abs(shap_values_Sejong_2.sum(1) + explainer_Sejong_2.expected_value - pred).max()

pred_Ulsan_1 =lgb_Ulsan_1.predict(test_Ulsan_1)
explainer_Ulsan_1 = shap.TreeExplainer(lgb_Ulsan_1)
shap_values_Ulsan_1 = explainer_Ulsan_1.shap_values(test_Ulsan_1)
np.abs(shap_values_Ulsan_1.sum(1) + explainer_Ulsan_1.expected_value - pred).max()

pred_Ulsan_2 =lgb_Ulsan_2.predict(test_Ulsan_2)
explainer_Ulsan_2 = shap.TreeExplainer(lgb_Ulsan_2)
shap_values_Ulsan_2 = explainer_Ulsan_2.shap_values(test_Ulsan_2)
np.abs(shap_values_Ulsan_2.sum(1) + explainer_Ulsan_2.expected_value - pred).max()

pred_Incheon_1 =lgb_Incheon_1.predict(test_Incheon_1)
explainer_Incheon_1 = shap.TreeExplainer(lgb_Incheon_1)
shap_values_Incheon_1 = explainer_Incheon_1.shap_values(test_Incheon_1)
np.abs(shap_values_Incheon_1.sum(1) + explainer_Incheon_1.expected_value - pred).max()

pred_Incheon_2 =lgb_Incheon_2.predict(test_Incheon_2)
explainer_Incheon_2 = shap.TreeExplainer(lgb_Incheon_2)
shap_values_Incheon_2 = explainer_Incheon_2.shap_values(test_Incheon_2)
np.abs(shap_values_Incheon_2.sum(1) + explainer_Incheon_2.expected_value - pred).max()

pred_Jeonnam_1 =lgb_Jeonnam_1.predict(test_Jeonnam_1)
explainer_Jeonnam_1 = shap.TreeExplainer(lgb_Jeonnam_1)
shap_values_Jeonnam_1 = explainer_Jeonnam_1.shap_values(test_Jeonnam_1)
np.abs(shap_values_Jeonnam_1.sum(1) + explainer_Jeonnam_1.expected_value - pred).max()

pred_Jeonbuk_1 =lgb_Jeonbuk_1.predict(test_Jeonbuk_1)
explainer_Jeonbuk_1 = shap.TreeExplainer(lgb_Jeonbuk_1)
shap_values_Jeonbuk_1 = explainer_Jeonbuk_1.shap_values(test_Jeonbuk_1)
np.abs(shap_values_Jeonbuk_1.sum(1) + explainer_Jeonbuk_1.expected_value - pred).max()

pred_Jeonbuk_2 =lgb_Jeonbuk_2.predict(test_Jeonbuk_2)
explainer_Jeonbuk_2 = shap.TreeExplainer(lgb_Jeonbuk_2)
shap_values_Jeonbuk_2 = explainer_Jeonbuk_2.shap_values(test_Jeonbuk_2)
np.abs(shap_values_Jeonbuk_2.sum(1) + explainer_Jeonbuk_2.expected_value - pred).max()

pred_Jeju_2 =lgb_Jeju_2.predict(test_Jeju_2)
explainer_Jeju_2 = shap.TreeExplainer(lgb_Jeju_2)
shap_values_Jeju_2 = explainer_Jeju_2.shap_values(test_Jeju_2)
np.abs(shap_values_Jeju_2.sum(1) + explainer_Jeju_2.expected_value - pred).max()

pred_Chungnam_1 =lgb_Chungnam_1.predict(test_Chungnam_1)
explainer_Chungnam_1 = shap.TreeExplainer(lgb_Chungnam_1)
shap_values_Chungnam_1 = explainer_Chungnam_1.shap_values(test_Chungnam_1)
np.abs(shap_values_Chungnam_1.sum(1) + explainer_Chungnam_1.expected_value - pred).max()

pred_Chungnam_2 =lgb_Chungnam_2.predict(test_Chungnam_2)
explainer_Chungnam_2 = shap.TreeExplainer(lgb_Chungnam_2)
shap_values_Chungnam_2 = explainer_Chungnam_2.shap_values(test_Chungnam_2)
np.abs(shap_values_Chungnam_2.sum(1) + explainer_Chungnam_2.expected_value - pred).max()

pred_Chungbuk_2 =lgb_Chungbuk_2.predict(test_Chungbuk_2)
explainer_Chungbuk_2 = shap.TreeExplainer(lgb_Chungbuk_2)
shap_values_Chungbuk_2 = explainer_Chungbuk_2.shap_values(test_Chungbuk_2)
np.abs(shap_values_Chungbuk_2.sum(1) + explainer_Chungbuk_2.expected_value - pred).max()

# %% [markdown]
#  SHAP on RandomForest

# %%
pred_Gangwon_1 = rf_Gangwon_1.predict(test_Gangwon_1)
explainer_Gangwon_1 = shap.TreeExplainer(rf_Gangwon_1)
shap_values_Gangwon_1 = explainer_Gangwon_1.shap_values(test_Gangwon_1)
np.abs(shap_values_Gangwon_1.sum(1) + explainer_Gangwon_1.expected_value - pred).max()

pred_Gangwon_2 = rf_Gangwon_2.predict(test_Gangwon_2)
explainer_Gangwon_2 = shap.TreeExplainer(rf_Gangwon_2)
shap_values_Gangwon_2 = explainer_Gangwon_2.shap_values(test_Gangwon_2)
np.abs(shap_values_Gangwon_2.sum(1) + explainer_Gangwon_2.expected_value - pred).max()

pred_Daegu_1 = rf_Daegu_1.predict(test_Daegu_1)
explainer_Daegu_1 = shap.TreeExplainer(rf_Daegu_1)
shap_values_Daegu_1 = explainer_Daegu_1.shap_values(test_Daegu_1)
np.abs(shap_values_Daegu_1.sum(1) + explainer_Daegu_1.expected_value - pred).max()

pred_Daejeon_1 = rf_Daejeon_1.predict(test_Daejeon_1)
explainer_Daejeon_1 = shap.TreeExplainer(rf_Daejeon_1)
shap_values_Daejeon_1 = explainer_Daejeon_1.shap_values(test_Daejeon_1)
np.abs(shap_values_Daejeon_1.sum(1) + explainer_Daejeon_1.expected_value - pred).max()

pred_Daejeon_1 = rf_Daejeon_1.predict(test_Daejeon_1)
explainer_Daejeon_1 = shap.TreeExplainer(rf_Daejeon_1)
shap_values_Daejeon_1 = explainer_Daejeon_1.shap_values(test_Daejeon_1)
np.abs(shap_values_Daejeon_1.sum(1) + explainer_Daejeon_1.expected_value - pred).max()

pred_Jeonnam_2 = rf_Jeonnam_2.predict(test_Jeonnam_2)
explainer_Jeonnam_2 = shap.TreeExplainer(rf_Jeonnam_2)
shap_values_Jeonnam_2 = explainer_Jeonnam_2.shap_values(test_Jeonnam_2)
np.abs(shap_values_Jeonnam_2.sum(1) + explainer_Jeonnam_2.expected_value - pred).max()

pred_Jeju_1 = rf_Jeju_1.predict(test_Jeju_1)
explainer_Jeju_1 = shap.TreeExplainer(rf_Jeju_1)
shap_values_Jeju_1 = explainer_Jeju_1.shap_values(test_Jeju_1)
np.abs(shap_values_Jeju_1.sum(1) + explainer_Jeju_1.expected_value - pred).max()

pred_Chungbuk_1 = rf_Chungbuk_1.predict(test_Chungbuk_1)
explainer_Chungbuk_1 = shap.TreeExplainer(rf_Chungbuk_1)
shap_values_Chungbuk_1 = explainer_Chungbuk_1.shap_values(test_Chungbuk_1)
np.abs(shap_values_Chungbuk_1.sum(1) + explainer_Chungbuk_1.expected_value - pred).max()

# %% [markdown]
# SHAP beeswarm plot (각 변수 값에 따라 예측 모델의 예측값 변동 방향, 크기의 분포)

# %%
# shap_values_시도_성별, test_시도_성별
shap.summary_plot(shap_values_Seoul_1, test_Seoul_1)

# %% [markdown]
# SHAP waterfall plot (개별 예측치에 대한 설명) for lgbm, Randomforest

# %%
 # lgb_시도_성별, test_시도_성별
explainer_seoul_1 = shap.Explainer(lgb_Seoul_1,test_Seoul_1) 
shap_values_seoul_1 = explainer_seoul_1(test_Seoul_1)

# rf_시도_성별, test_시도_성별
explainer_Daegu_1 = shap.TreeExplainer(rf_Daegu_1,test_Daegu_1) 
shap_values_Daegu_1 = explainer_Daegu_1(test_Daegu_1)

# %%
# shap_values_시도_성별[예측치 index]
shap.plots.waterfall(shap_values_Daegu_1[3], max_display=20)
